# %%
import matplotlib.pyplot as plt
import PIL
import os
import pytesseract
# %matplotlib inline

# %%
os.chdir('C:/Users/ELCOT/desktop')

# %%
img = PIL.Image.open('testbill.JPEG')
plt.imshow(img)

# %%
pytesseract.pytesseract.tesseract_cmd= 'C:/Program Files/Tesseract-OCR/tesseract'
TESSDATA_PREFIX='C:/Program Files/Tesseract-OCR'

# %%
text_data = pytesseract.image_to_string(img.convert('RGB'), lang='eng')

# %%
print(text_data)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
# 0007108
#
# id SEVEN HILL PERFECT WEIGH BRIDGE
#
# pO ne Stuur rane. Civanc|
# SF.389/2, Tiruvottiyur Simoes ve Vilangadu Pp. ahdion ;
# Chennai - 600 052,
#
# Cell 98410 5 5494
# 100 TONNES C COMPUTERISED ELECTRONIC WEIGH BRIDGE
#
# Weighment Certificate page: 6
#
# Vehicle No. : *
#
# Serial No. :
#
#
#
# | We. Charges ’
# Material
#
#
#
# O9229306
# 20/10/2021

# %%
print(16384%676)
# Out:
# 160

# %%
print(160/26)
# Out:
# 6.153846153846154

# %%
print(134%26)
# Out:
# 4
